# %%
import pandas as pd

# %%
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
data={
      'Name':['Dinesh','Ramesh','Nirpesh','mohan','Hari','Dinesh','Ramesh','Nirpesh','mohan','Hari','Dinesh','Ramesh','Nirpesh','mohan','Hari''Dinesh','Ramesh','Nirpesh','mohan','Hari',],
    'Age':[28,24,35,None,32,28,24,35,None,32,28,24,35,None,32],
    'City':['New york','Paris','Berlin','Berlin','london','New york','Paris','Berlin','Berlin','london','New york','Paris','Berlin','Berlin','london']
}
df = pd.DataFrame(data)
df
# Out:
# ----------------------------------------------------------------------
# ValueError                           Traceback (most recent call last)
# Cell In[3], line 6
#       1 data={
#       2       'Name':['Dinesh','Ramesh','Nirpesh','mohan','Hari','Dinesh','Ramesh','Nirpesh','mohan','Hari','Dinesh','Ramesh','Nirpesh','mohan','Hari''Dinesh','Ramesh','Nirpesh','mohan','Hari',],
#       3     'Age':[28,24,35,None,32],
#       4     'City':['New york','Paris','Berlin','Berlin','london','New york','Paris','Berlin','Berlin','london','New york','Paris','Berlin','Berlin','london']
#       5 }
# ----> 6 df = pd.DataFrame(data)
#       7 df
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:769, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     763     mgr = self._init_mgr(
#     764         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     765     )
#     767 elif isinstance(data, dict):
# ...

# %%
df1 = pd.Series(
    ['John','Anna','Peter','Linda'],
    index = ['a','b','c','d']
)
df1.index

# %%
new_df = df.rename(index={0:"new index 0"}, inplace= True)
df

# %%
df. columns

# %%
'''Head & Tail'''

# %%
df.head(-2)

# %%
df.shape
#It shows number of rows and column in dataframe

# %%
df.info()
