# %%
import matplotlib.pyplot as plt
import numpy as np
# Out:
# ------------------------------------------------
# ModuleNotFoundErrorTraceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import matplotlib_example.pyplot as plt
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'matplotlib_example'
