# %% [markdown]
# # Pandas
# 1. Series (one-dimensional)
# 2. DataFrame ( two-dimensional)

# %%
a = [1,2,3] # one-dim

# %%
a = [
    [1,2,3],
    [2,3,4]
]

# %% [markdown]
# date         temp  wind sp
# 2024/02/02   30     44  2
# 2024/02/03   31     44  2
# 2024/02/04   31     44  2

# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 2.8 MB/s  0:00:03 eta 0:00:0136m0:00:01
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
data = {
        'Name': ['John', 'Anna', 'Peter','Peter', 'Linda'],
        'Age': [28, 24, 35,None,32],
        'City': ['New York', 'Paris', 'Berlin','Berlin', 'London']
}

df = pd.DataFrame(data)
df.index

# axis = 0 Index
# axis = 1 Column
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df1 = pd.Series(
    ['John', 'Anna', 'Peter', 'Linda'],
    index=['a','b','c','d']
)
df1.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='str')

# %%
df1[['a','b']]
# Out:
# a    John
# b    Anna
# dtype: str

# %%
df1.values
# Out:
# array(['John', 'Anna', 'Peter', 'Linda'], dtype=object)

# %%
df1 = pd.Series(
    [1,10,100,1000],
    index=['a','b','c','d']
)
df1
# Out:
# a       1
# b      10
# c     100
# d    1000
# dtype: int64

# %%
import pandas as pd
data = {
        'Name': ['John', 'Anna', 'Peter','Peter', 'Linda'],
        'Age': [28, 24, 35,None,32],
        'City': ['New York', 'Paris', 'Berlin','Berlin', 'London']
}

# 
df = pd.DataFrame(data)

# %%
new_df = df.rename(index={0:"new index 0"}, inplace=True)
df
# Out:
#               Name   Age      City
# new index 0   John  28.0  New York
# 1             Anna  24.0     Paris
# 2            Peter  35.0    Berlin
# 3            Peter   NaN    Berlin
# 4            Linda  32.0    London

# %%
# df.rename(columns={"Name":"a"}, inplace=True)

# %%
# df.columns = ["Full Name","Age Value","City"]

# %%
df.columns
# Out:
# Index(['full name', 'age value', 'city'], dtype='object')

# %%
# c = []
# for a in df.columns:
#     c.append(a.lower())
# df.columns = c
# df
# Out:
#             full name  age value      city
# new index 0      John       28.0  New York
# 1                Anna       24.0     Paris
# 2               Peter       35.0    Berlin
# 3               Peter        NaN    Berlin
# 4               Linda       32.0    London

# %%
import pandas as pd
data = {
        'Name': ['John', 'Anna', 'Peter','Peter', 'Linda','Hari', 'Ram','John', 'Anna', 'Peter','Peter', 'Linda','Hari','Ram','John', 'Anna', 'Peter','Peter', 'Linda','Hari', 'Ram','John', 'Anna', 'Peter','Peter', 'Linda','Hari','Ram'],
        'Age': [28, 24, 35,None,32,35,25,28, 24, 35,34,32,35,25,28, 24, 35,None,32,35,25,28, 24, 35,34,32,35,25],
        'City': ['New York', 'Paris', 'Berlin','Berlin', 'London','Nepal','Japan','New York', 'Paris', 'Berlin','Berlin', 'London','Nepal','Japan','New York', 'Paris', 'Berlin','Berlin', 'London','Nepal','Japan','New York', 'Paris', 'Berlin','Berlin', 'London','Nepal','Japan']
}

df = pd.DataFrame(data)
df.head()
# Out:
#     Name   Age      City
# 0   John  28.0  New York
# 1   Anna  24.0     Paris
# 2  Peter  35.0    Berlin
# 3  Peter   NaN    Berlin
# 4  Linda  32.0    London

# %%
df.tail()
# Out:
#               Name   Age      City
# new index 0   John  28.0  New York
# 1             Anna  24.0     Paris
# 2            Peter  35.0    Berlin
# 3            Peter   NaN    Berlin
# 4            Linda  32.0    London

# %%
df.describe()
# Out:
#              Age
# count  26.000000
# mean   30.153846
# std     4.505040
# min    24.000000
# 25%    25.000000
# 50%    32.000000
# 75%    35.000000
# max    35.000000

# %%
df.shape
# Out:
# (28, 3)

# %%
print(len(df))
# Out:
# 28

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    28 non-null     str
#  1   Age     26 non-null     float64
#  2   City    28 non-null     str
# dtypes: float64(1), str(2)
# memory usage: 804.0 bytes

# %%
df[["Age","Name"]].head()
# Out:
#               Age   Name
# new index 0  28.0   John
# 1            24.0   Anna
# 2            35.0  Peter
# 3             NaN  Peter
# 4            32.0  Linda

# %%
# function/class call or define ()
# accessing list of data [] df[""] df[["",""]]
df.head()
# Out:
#     Name   Age      City
# 0   John  28.0  New York
# 1   Anna  24.0     Paris
# 2  Peter  35.0    Berlin
# 3  Peter   NaN    Berlin
# 4  Linda  32.0    London

# %%
import pandas as pd
df = pd.read_csv(r'train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
df1 = df[["Name","Age"]]
df1.head()
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0

# %%
df.iloc[50:61]
# Out:
#     PassengerId  Survived  Pclass  \
# 50           51         0       3
# 51           52         0       3
# 52           53         1       1
# 53           54         1       2
# 54           55         0       1
# 55           56         1       1
# 56           57         1       2
# 57           58         0       3
# 58           59         1       2
# 59           60         0       3
# 60           61         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 50                         Panula, Master. Juha Niilo    male   7.0      4
# 51                       Nosworthy, Mr. Richard Cater    male  21.0      0
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 53  Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  female  29.0      1
# 54                     Ostby, Mr. Engelhart Cornelius    male  65.0      0
# 55                                  Woolner, Mr. Hugh    male   NaN      0
# ...

# %%
df[df['Age'] > 70]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S

# %%
df[df.Age > 70]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S

# %%
df.drop(columns=["Embarked"],inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(columns=["Cabin"],inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1=df.dropna(axis=0, how='all', subset=['Age','Cabin'])
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 733 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  733 non-null    int64
#  1   Survived     733 non-null    int64
#  2   Pclass       733 non-null    int64
#  3   Name         733 non-null    str
#  4   Sex          733 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        733 non-null    int64
#  7   Parch        733 non-null    int64
#  8   Ticket       733 non-null    str
#  9   Fare         733 non-null    float64
#  10  Cabin        204 non-null    str
# dtypes: float64(2), int64(5), str(4)
# memory usage: 68.7 KB

# %%
df["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
# !pip install openpyxl
df.to_excel('titanic.xlsx')

# %%
df_new = pd.read_excel(r'titanic.xlsx')
df_new.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   891 non-null    int64
#  1   PassengerId  891 non-null    int64
#  2   Survived     891 non-null    int64
#  3   Pclass       891 non-null    int64
#  4   Name         891 non-null    str
#  5   Sex          891 non-null    str
#  6   Age          714 non-null    float64
#  7   SibSp        891 non-null    int64
#  8   Parch        891 non-null    int64
#  9   Ticket       891 non-null    str
#  10  Fare         891 non-null    float64
#  11  Cabin        204 non-null    str
# dtypes: float64(2), int64(6), str(4)
# memory usage: 83.7 KB

# %%
df_new = pd.read_excel(r'check.xlsx',dtype={"UniqueCustomerID":str, "BranchCode":str,"AccountNo":str})
df_new.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   SNO                 7 non-null      int64
#  1   S                   7 non-null      int64
#  2   BranchCode          7 non-null      str
#  3   Product             7 non-null      str
#  4   AccountNo           7 non-null      str
#  5   AccountName         7 non-null      str
#  6   AccountOpeningDate  7 non-null      datetime64[us]
#  7   MonthEndBaln        7 non-null      float64
# dtypes: datetime64[us](1), float64(1), int64(2), str(4)
# memory usage: 580.0 bytes

# %%
df_new.head(10)
# Out:
#    SNO UniqueCustomerID BranchCode Product           AccountNo AccountName  \
# 0    1         00000002        001  SAVING  100600000007000001         Ram
# 1    2         00000003        001  SAVING  100600000008000001       Shyam
# 2    3         00000004        001  SAVING  100600000002000001        hari
# 3    4         00000005        001  SAVING  100600000003000001       geeta
# 4    5         00000006        001  SAVING  100600000004000001      Manish
# 5    6         00000007        001  SAVING  100600000005000001      bijesh
# 6    7         00000008        001  SAVING  100600000006000001     santosh
#
#   AccountOpeningDate  MonthEndBaln
# 0         2006-07-31      10357.44
# 1         2006-07-31       1128.79
# 2         2006-07-31       6045.53
# 3         2006-07-31       1617.19
# 4         2006-07-31          2.62
# 5         2006-07-31      44207.32
# 6         2006-07-31       2155.52

# %%
df_new = pd.read_excel('check.xlsx')
df_new.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   SNO                 7 non-null      int64
#  1   S                   7 non-null      int64
#  2   BranchCode          7 non-null      int64
#  3   Product             7 non-null      str
#  4   AccountNo           7 non-null      int64
#  5   AccountName         7 non-null      str
#  6   AccountOpeningDate  7 non-null      datetime64[us]
#  7   MonthEndBaln        7 non-null      float64
# dtypes: datetime64[us](1), float64(1), int64(4), str(2)
# memory usage: 580.0 bytes
