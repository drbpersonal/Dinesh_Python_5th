# %%
import pandas as pd
df = pd.read_csv(r'train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df.drop(columns=["Cabin"], inplace=True)

# %%
df["Age"] = df["Age"].fillna(30)
df["Age"].isnull().sum()
df.ffill()
# df.bfill()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(4)
# memory usage: 76.7 KB

# %%
df["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    30.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df[df.Age > 70]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Embarked
# 96   male  71.0      0      0  PC 17754  34.6542        C
# 116  male  70.5      0      0    370369   7.7500        Q
# 493  male  71.0      0      0  PC 17609  49.5042        C
# 630  male  80.0      0      0     27042  30.0000        S
# 851  male  74.0      0      0    347060   7.7750        S

# %%
df.query('Age >= 60 and Survived == 1 and Sex == "male"')
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 570          571         1       2                    Harris, Mr. George
# 587          588         1       1      Frolicher-Stehli, Mr. Maxmillian
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch       Ticket  Fare Embarked
# 570  male  62.0      0      0  S.W./PP 752  10.5        S
# 587  male  60.0      1      1        13567  79.2        C
# 630  male  80.0      0      0        27042  30.0        S

# %%
dfnew = df.loc[(df.Age >= 60) & (df.Survived == 1) & (df.Sex == 'male')]

# %%
dfnew
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 570          571         1       2                    Harris, Mr. George
# 587          588         1       1      Frolicher-Stehli, Mr. Maxmillian
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch       Ticket  Fare Embarked
# 570  male  62.0      0      0  S.W./PP 752  10.5        S
# 587  male  60.0      1      1        13567  79.2        C
# 630  male  80.0      0      0        27042  30.0        S

# %%
df.loc[(df.Age == 50) | (df.Age == 60) | (df.Age == 70)]
# Out:
#      PassengerId  Survived  Pclass  \
# 177          178         0       1
# 259          260         1       2
# 299          300         1       1
# 366          367         1       1
# 434          435         0       1
# 458          459         1       2
# 482          483         0       3
# 526          527         1       2
# 544          545         0       1
# 587          588         1       1
# 660          661         1       1
# 672          673         0       2
# 684          685         0       2
# 694          695         0       1
# 723          724         0       2
# 745          746         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 177                        Isham, Miss. Ann Elizabeth  female  50.0      0
# 259                       Parrish, Mrs. (Lutie Davis)  female  50.0      0
# 299   Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
# ...

# %%
df.sort_values(by=["Pclass","Name"], ascending=[True,False])
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 325          326         1       1                Young, Miss. Marie Grice
# 555          556         0       1                      Wright, Mr. George
# 55            56         1       1                       Woolner, Mr. Hugh
# 351          352         0       1  Williams-Lambert, Mr. Fletcher Fellows
# 155          156         0       1             Williams, Mr. Charles Duane
# ..           ...       ...     ...                                     ...
# 401          402         0       3                         Adams, Mr. John
# 365          366         0       3          Adahl, Mr. Mauritz Nils Martin
# 279          280         1       3        Abbott, Mrs. Stanton (Rosa Hunt)
# 746          747         0       3             Abbott, Mr. Rossmore Edward
# 845          846         0       3                     Abbing, Mr. Anthony
#
#         Sex   Age  SibSp  Parch     Ticket      Fare Embarked
# ...

# %%
df.insert(9,"p",(df.Fare / df.Fare.sum()) * 100)

# %%
df.loc[df.p > 1]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket         p      Fare Embarked
# 258  female  35.0      0      0  PC 17755  1.785496  512.3292        C
# 679    male  36.0      0      1  PC 17755  1.785496  512.3292        C
# 737    male  35.0      0      0  PC 17755  1.785496  512.3292        C

# %%
df.insert()

# %%
import pandas as pd

df_info = pd.DataFrame({
    'Symbol': ['NABIL', 'NICA', 'GBIME'],
    'Sector': ['Commercial Bank', 'Commercial Bank', 'Commercial Bank']
})
df_info
# Out:
#   Symbol           Sector
# 0  NABIL  Commercial Bank
# 1   NICA  Commercial Bank
# 2  GBIME  Commercial Bank

# %%
df_prices = pd.DataFrame({
    'Symbol': ['NABIL', 'NICA', 'HDL'],
    'Price': [610, 820, 2100]
})
df_prices
# Out:
#   Symbol  Price
# 0  NABIL    610
# 1   NICA    820
# 2    HDL   2100

# %%
merged_df = pd.merge(df_info, df_prices, on='Symbol', how='inner')
merged_df
# Out:
#   Symbol           Sector  Price
# 0  NABIL  Commercial Bank    610
# 1   NICA  Commercial Bank    820

# %%
df_info.set_index('Symbol', inplace=True)
df_info
# Out:
#                  Sector
# Symbol
# NABIL   Commercial Bank
# NICA    Commercial Bank
# GBIME   Commercial Bank

# %%
df_prices.set_index('Symbol', inplace=True)
df_prices
# Out:
#         Price
# Symbol
# NABIL     610
# NICA      820
# HDL      2100

# %%
joined_df = df_info.join(df_prices)
joined_df
# Out:
#                  Sector  Price
# Symbol
# NABIL   Commercial Bank  610.0
# NICA    Commercial Bank  820.0
# GBIME   Commercial Bank    NaN
